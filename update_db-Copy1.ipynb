# %%
import requests, csv
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
from collections import OrderedDict
import tqdm

# %%
def movie_imdb(imdb_id):

    #SELECT SYNOPSIS, GENRES, RATING, NUMBER RATE, YEAR, TITLE, ORIGINAL TITLE, COUNTRY,
    #SELECT LANGUAGE, BUDGET

    r1 = requests.get("https://www.imdb.com/title/"+imdb_id)
    bs = BeautifulSoup(r1.text, "html.parser")

    # Dictionnary for title, orginal_title, rating, num_rate

    info_dict = bs.find('script', {'type': 'application/ld+json'})
    info_dict = info_dict.text
    info_dict = OrderedDict(eval(info_dict))

    original_title = info_dict["name"]

    if original_title.find("&apos;") != -1:
        original_title = original_title.replace("&apos;", "'")

    if original_title.find("&amp") != -1:
        original_title = original_title.replace("&amp", "&")

    try :
        title = info_dict["alternateName"]
    except KeyError:
        title = info_dict["name"]

    if title.find("&amp") != -1:
        title = title.replace("&amp", "&")

    if title.find("&apos;") != -1:
        title = title.replace("&apos;", "'")

    try :
        rating = info_dict['aggregateRating']['ratingValue']
        num_rate = int(info_dict['aggregateRating']['ratingCount'])
    except KeyError:
        rating = ""
        num_rate = ""

    # Info budget bud_currency

    try:
        info_bud = bs.findAll('section', {'data-testid': 'BoxOffice'})
        info_bud = [text.text for text in info_bud][0]
        price = info_bud.split("EditBudget")[1].split(" ")[0]
        budget = int(price[1:].replace(',',''))
        bud_currency = price[0]
    except (IndexError, ValueError):
        budget = ""
        bud_currency = ""


    # Info YEAR

    year = bs.findAll('a', {'class': re.compile('ipc-link')})
    year = int([text.text for text in year][0].strip("– "))

    # Info genres
    genre_bs = bs.findAll('a', {'class': re.compile('ipc-metadata-list-item')})
    genre_bs = [text.text for text in genre_bs]

    genre_list = ["Action", "Adult", "Adventure", "Animation", "Biography", "Comedy", "Crime", "Documentary",
              "Drama", "Family", "Fantasy", "Film-Noir", "History", "Horror", "Music", "Musical", "Mystery",
              "News", "Reality-TV", "Romance", "Sci-Fi", "Short", "Sport", "Thriller", "War", "Western"]

    genres = [genre for genre in genre_bs if genre in genre_list]

    # Info SYNOPSIS
    try :
        syn = bs.findAll('div', {'class': 'ipc-html-content ipc-html-content--base'})[0]
        syn = [text.text for text in syn]
        synopsis = syn[0].split(" —")[0]
    except IndexError:
        synopsis = ""


    countries = bs.findAll('a', {'href': re.compile('country_of_origin')})
    if len(countries) == 0:
        country = ['None']
    else:
        country = ["USA" if text.text == "United States" else "UK" if text.text == "United Kingdom" \
                    else text.text for text in countries]


    language = bs.findAll('a', {'href': re.compile('primary_language')})
    if len(language) == 0:
        language = ["No Info"]
    else :
        language = [text.text for text in language]


    #SELECT CASTING, DIRECTOR, WRITERS

    r2 = requests.get("https://www.imdb.com/title/"+imdb_id+"/fullcredits")
    bs2 = BeautifulSoup(r2.text, "html.parser")

    #select casting
    cast_list = bs2.find_all('table', {'class': 'cast_list'})
    if cast_list == None or cast_list == []:
        cast = [""]
        cast_code = [""]
        cast_voice = [""]
    else :
        cast_list_test = bs2.find('table', {'class': 'cast_list'}).find_all('td', {'class':'primary_photo'})
        cast_list_char = bs2.find('table', {'class': 'cast_list'}).find_all('td', {'class':'character'})
        cast_char = [text.text.strip().replace(' \n', '') for text in cast_list_char]
        if len(cast_list_test) >= 30 :
            cast = [str(cast_list).split('img alt="')[i].split('" class="')[0] for i in range(1,31)]
            cast_code = [str(cast_list_test).split('/name/')[i].split('/">')[0] for i in range(1,31)]
            cast_voice = ["V" if "(voice)" in text else "U" if "uncredited" in text else "" \
                          for text in cast_char[:30]]
        else :
            cast = [str(cast_list).split('img alt="')[i].split('" class="')[0] \
                    for i in range(1,len(cast_list_test)+1)]
            cast_code = [str(cast_list_test).split('/name/')[i].split('/">')[0] \
                          for i in range(1,len(cast_list_test)+1)]
            cast_voice = ["V" if "(voice)" in text else "U" if "uncredited" in text else "" \
                          for text in cast_char[:len(cast_list_test)]]


    #select director
    test_dir = bs2.find('h4', {'id':'director'})
    if test_dir == None:
        director = [""]
        dir_code = [""]
    else :
        direct = bs2.find('table', {'class': 'simpleTable simpleCreditsTable'}) \
                .find_all('td', {'class': 'name'})
        direct_t = [text.text for text in direct]
        director = [i.strip() for i in direct_t]
        dir_code = [(str(direct).split('href="/name/')[i+1]).split('/"> ')[0] for i in range(len(director))]

    #SELECT RUNTIME

    r3 = requests.get("https://www.imdb.com/title/"+imdb_id+"/technical")
    bs3 = BeautifulSoup(r3.text, "html.parser")

    time = bs3.find('table', {'class': 'dataTable labelValueTable'}).find_all('tr', {'class': 'odd'})
    runtime = [text.text for text in time]
    try:
        if ("min (" in (runtime[0].strip())) and (" min)" in (runtime[0].strip())):
            duration = int((runtime[0].strip().split("min (")[1]).split(" min)")[0])
        elif "hr (" in (runtime[0].strip()):
            duration = int((runtime[0].strip().split("hr (")[1]).split(" min)")[0])
        else :
            duration = int((runtime[0].strip().split("Runtime")[1]).split(" min")[0])
    except (ValueError, IndexError):
        duration = ""


    #SELECT PRODUCTION

    r4 = requests.get("https://www.imdb.com/title/"+imdb_id+"/companycredits")
    bs4 = BeautifulSoup(r4.content, "html.parser")
    test = bs4.find('h4', {'id': 'production'})
    if test == None:
        production = [""]
        prod_code = [""]
    else :
        prod_list = bs4.find('ul', {'class': 'simpleList'}).find_all("li")
        prod_t = [text.text.strip() for text in prod_list]
        production = [pro.split("   ")[0] if "   " in pro else pro for pro in prod_t]

        prod_code = [(str(i).split("pany/")[1]).split('">')[0] for i in prod_list]

    if rating != "":
        return imdb_id, title, original_title, year, director, dir_code, cast, cast_code, cast_voice, genres, duration, \
        country, language, production, prod_code, synopsis, rating, num_rate, budget, bud_currency
    else:
        return imdb_id, title,"","","","","","","","","","","","","","","","","",""

# %%
df = pd.read_csv('movies_to_scrap/scrap_it.csv')

# %%
imdb_id = df["imdb"].values

# %%
db_df = pd.read_csv('db_backup/movies_db.csv')

# %%
imdb_db = db_df["imdb_id"].values

# %%
final_imdb = [i for i in imdb_id if i not in imdb_db]

# %%
final_imdb
# Out:
# ['tt16579354', 'tt6013920', 'tt11286314']

# %%
movies = []

# %%
for movie in tqdm.tqdm(imdb_id):
    movies.append(movie_imdb(movie))
# Out:
# 100%|██████████| 18/18 [01:02<00:00,  3.45s/it]

# %%
movies
# Out:
# [('tt13723064',
#   'Tous mes amis sont morts',
#   'Wszyscy moi przyjaciele nie zyja',
#   2020,
#   ['Jan Belcl'],
#   ['nm5282441'],
#   ['Michal Meyer',
#    'Adam Woronowicz',
#    'Julia Wieniawa-Narkiewicz',
#    'Adam Turczyk',
#    'Nikodem Rozbicki',
#    'Monika Krzywkowska',
#    'Szymon Roszak',
#    'Michal Sikorski',
#    'Adam Bobik',
#    'Tomasz Karolak',
#    'Mateusz Wieclawek',
#    'Yassine Fadel',
#    'Bartlomiej Firlet',
#    'Wojciech Lozowski',
#    'Aleksandra Pisula',
#    'Paulina Galazka',
#    'Magdalena Perlinska',
#    'Konrad Zygadlo',
#    'Katarzyna Chojnacka',
#    'Kamil Piotrowski',
#    'Dominika Sakowicz',
#    'Barbara Garstka',
#    'Mattia Rosinski',
#    'Jaroslaw Boberek',
#    'Ewa Kania',
#    'Elie Rosinski',
#    'Ewa Grygo',
#    'Izabela Grygo',
#    'Rafal Rosiak',
#    'Maciej Dabrowski'],
#   ['nm3130314',
#    'nm0941575',
#    'nm8709489',
#    'nm8432916',
#    'nm5279667',
#    'nm0473102',
#    'nm6379052',
#    'nm9300957',
#    'nm5216205',
#    'nm0439878',
#    'nm5851110',
#    'nm4475248',
#    'nm3654338',
#    'nm3061478',
#    'nm7911623',
#    'nm4502311',
#    'nm12186842',
#    'nm9112048',
#    'nm10599047',
#    'nm10658884',
#    'nm9659514',
#    'nm5316962',
#    'nm10882083',
#    'nm0090353',
#    'nm0437694',
#    'nm12186843',
#    'nm12186844',
#    'nm4988881',
#    'nm4888523',
#    'nm12186845'],
#   ['',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    'V',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    'V',
#    'V',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['Comedy', 'Crime', 'Drama'],
#   96,
#   ['Poland'],
#   ['Polish', 'French'],
#   ['Aurum Film'],
#   ['co0517033'],
#   "During the New Year's Eve party of a bunch of friends, a series of crazy events brings out secrets, breaks hearts and leads to a shocking ending.",
#   5.8,
#   5921,
#   '',
#   ''),
#  ('tt8493970',
#   "L'ennemi",
#   "L'ennemi",
#   2020,
#   ['Stephan Streker'],
#   ['nm1437690'],
#   ['Jérémie Renier',
#    'Alma Jodorowsky',
#    'Emmanuelle Bercot',
#    'Félix Maritaud',
#    'Zacharie Chasseriaud',
#    'Sam Louwyck',
#    'Peter Van den Begin',
#    'Bruno Vanden Broecke',
#    'Jeroen Perceval',
#    'Consolate Siperius',
#    'Stefan Jakiela',
#    'Kevin Bellemans',
#    'Édith Le Merdy',
#    'Hervé Sogne',
#    'Olivier Paquin',
#    'Robin Keyaert',
#    'Andy Van Kerschaver',
#    'Oscar Willems',
#    'Kristof Verhassel',
#    'Samuel Van der Zwalmen',
#    'Félix Driesen',
#    'Tom Viaene',
#    'Marie-Ange Gillis',
#    'Emily Jasmin Decoussemaeker',
#    'Elisabeth Chuffart',
#    'Mickey Hardt',
#    'Gilles Soeder',
#    'Jonathan Leoni',
#    'Nathan Smekens',
#    'Tom De Vreese'],
#   ['nm0753737',
#    'nm2300160',
#    'nm0073384',
#    'nm9029751',
#    'nm2165214',
#    'nm0522205',
#    'nm0886045',
#    'nm0888652',
#    'nm2334765',
#    'nm9824641',
#    'nm7805811',
#    'nm1567094',
#    'nm0501258',
#    'nm0812223',
#    'nm11538077',
#    'nm8213628',
#    'nm4697978',
#    'nm5743745',
#    'nm0894150',
#    'nm8404755',
#    'nm11538078',
#    'nm3654404',
#    'nm3677554',
#    'nm5048907',
#    'nm8304348',
#    'nm0362510',
#    'nm0812081',
#    'nm12351506',
#    'nm12351507',
#    'nm7562208'],
#   ['',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    'U'],
#   ['Crime', 'Drama'],
#   105,
#   ['Belgium', 'France', 'Luxembourg'],
#   ['French', 'Flemish'],
#   ['Daylight Films',
#    'Formosa Productions',
#    'BAC Cinéma',
#    'Radio Télévision Belge Francophone (RTBF)',
#    'Proximus',
#    'VOO',
#    'BE TV',
#    'Libellule Production',
#    'Polaris Film Production & Finance',
#    'BNP Paribas Fortis Film Finance',
#    "Centre du Cinéma et de l'Audiovisuel de la Fédération Wallonie-Bruxelles",
#    'Film Fund Luxembourg',
#    'Région de Bruxelles-Capitale',
#    'MEDIA Programme of the European Union',
#    'Philophon'],
#   ['co0592341',
#    'co0097625',
#    'co0847566',
#    'co0011677',
#    'co0511943',
#    'co0375934',
#    'co0178188',
#    'co0847567',
#    'co0378200',
#    'co0351494',
#    'co0009031',
#    'co0079186',
#    'co0704817',
#    'co0004166',
#    'co0328215'],
#   'Prominent politician Louis Durieux is accused of having murdered his wife, found dead in their hotel room. The case blows up into an intense media storm. Is he guilty or innocent? Nobody knows. Perhaps not even him.',
#   6.7,
#   81,
#   '',
#   ''),
#  ('tt10986222',
#   "Nos âmes d'enfants",
#   "C'mon C'mon",
#   2021,
#   ['Mike Mills'],
#   ['nm0590122'],
#   ['Joaquin Phoenix',
#    'Gaby Hoffmann',
#    'Woody Norman',
#    'Scoot McNairy',
#    'Molly Webster',
#    'Jaboukie Young-White',
#    'Deborah Strang',
#    'Sunni Patterson',
#    'Jenny Eliscu',
#    'Mary Passeri',
#    'Brandon Rush',
#    "Brey'on Shaw",
#    "Todd d'Amour",
#    'Beth Bartley',
#    'Artrial Clark',
#    'Eleanor Halm Simmons',
#    'Keisuke Hoashi',
#    'Maximilla Lukacs',
#    'Nancy Gell',
#    'Gita Reddy',
#    'Mya Gonzales',
#    'Cooper Jack Rubin',
#    'Faith Steptore',
#    'Mahfuzul Islam',
#    'Sophie Suzuki Shih',
#    'Kate Adams',
#    'Callan Farris',
#    'Elaine Kagan',
#    'Khadija Emma Neumann',
#    'Brian Plaideau'],
#   ['nm0001618',
#    'nm0000451',
#    'nm7035760',
#    'nm1058940',
#    'nm6701762',
#    'nm7187850',
#    'nm0833338',
#    'nm5455438',
#    'nm1722936',
#    'nm2755979',
#    'nm3614628',
#    'nm13000068',
#    'nm2350219',
#    'nm6467789',
#    'nm6564483',
#    'nm13000069',
#    'nm0387521',
#    'nm2058262',
#    'nm13000070',
#    'nm1012020',
#    'nm5636837',
#    'nm10131331',
#    'nm13000071',
#    'nm9433823',
#    'nm9776460',
#    'nm8116132',
#    'nm7986575',
#    'nm0330813',
#    'nm10466245',
#    'nm10596407'],
#   ['',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    'U',
#    'U',
#    'U',
#    'U',
#    'U'],
#   ['Drama'],
#   109,
#   ['USA'],
#   ['English'],
#   ['A24', 'Be Funny When You Can'],
#   ['co0390816', 'co0879142'],
#   'When his sister asks him to look after her son, a radio journalist embarks on a cross-country trip with his energetic nephew to show him life away from Los Angeles.',
#   7.6,
#   12610,
#   '',
#   ''),
#  ('tt11956066',
#   'Souterrain',
#   'Souterrain',
#   2020,
#   ['Sophie Dupuis'],
#   ['nm2876079'],
#   ['Joakim Robillard',
#    'Jean-François Boudreau',
#    'Guillaume Cyr',
#    'Chantal Fontaine',
#    'Maxime Genois',
#    'Mickaël Gouin',
#    'Lauren Hartley',
#    'Charles-Aubey Houde',
#    'James Hyndman',
#    "Jean L'Italien",
#    'Bruno Marcil',
#    'Théodore Pellerin',
#    'Catherine Trudeau'],
#   ['nm8873841',
#    'nm1047757',
#    'nm2280428',
#    'nm0284785',
#    'nm7161842',
#    'nm4358638',
#    'nm8357370',
#    'nm11380291',
#    'nm0405247',
#    'nm0478331',
#    'nm3048719',
#    'nm6829691',
#    'nm0874028'],
#   ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#   ['Drama'],
#   97,
#   ['Canada'],
#   ['French'],
#   ['Bravo Charlie',
#    'Bord Cadre Films',
#    'SODEC',
#    'Sovereign Films (II)',
#    'The Harold Greenberg Fund',
#    'Téléfilm Canada'],
#   ['co0664701',
#    'co0149598',
#    'co0299307',
#    'co0137361',
#    'co0130269',
#    'co0053578'],
#   'Maxime is a miner with a troubled past. After an explosion at his mine, Maxime attempts to find redemption by saving his fellow miners.',
#   7.1,
#   208,
#   '',
#   ''),
#  ('tt11087960',
#   'Un monde',
#   'Un monde',
#   2021,
#   ['Laura Wandel'],
#   ['nm3218491'],
#   ['Maya Vanderbeque',
#    'Günter Duret',
#    'Lena Girard Voss',
#    'Simon Caudry',
#    'Thao Maerten',
#    'James Seguy',
#    'Naël Ammama',
#    'Émile Salamone',
#    'Karim Leklou',
#    'Laura Verlinden',
#    'Laurent Capelluto',
#    'Sandrine Blancke',
#    'Monia Douieb',
#    'Michel Israël',
#    'Sophia Leboutte',
#    'Muriel Bersy',
#    'Kylian Decorne',
#    'Anne-Pascale Clairembourg',
#    'Marie-Christine Georges',
#    'Jean-François Ravagnan'],
#   ['nm11042810',
#    'nm10108593',
#    'nm9708142',
#    'nm6497350',
#    'nm9837454',
#    'nm13328632',
#    'nm13328633',
#    'nm12469066',
#    'nm3588254',
#    'nm2539653',
#    'nm0135084',
#    'nm0087207',
#    'nm2122304',
#    'nm0411473',
#    'nm0495844',
#    'nm0077781',
#    'nm13328634',
#    'nm1148206',
#    'nm13328635',
#    'nm3753499'],
#   ['',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    'V'],
#   ['Drama'],
#   72,
#   ['Belgium'],
#   ['French'],
#   ['Dragons Films',
#    'Lunanime',
#    "Centre du Cinéma et de l'Audiovisuel de la Fédération Wallonie-Bruxelles",
#    'Vlaams Audiovisueel Fonds',
#    'Wallimage',
#    'VOO',
#    'BE TV'],
#   ['co0211102',
#    'co0310366',
#    'co0009031',
#    'co0109106',
#    'co0097237',
#    'co0375934',
#    'co0178188'],
#   "When Nora witnesses Abel being bullied by other kids, she rushes to protect him. But Abel forces her to remain silent. Caught in a conflict of loyalty, Nora tries to find her place, torn between children's and adult's worlds.",
#   7.3,
#   847,
#   1000000,
#   '€'),
#  ('tt15067124',
#   'Municipale',
#   'Municipale',
#   2021,
#   ['Thomas Paulot'],
#   ['nm12766683'],
#   ['Laurent Papot', 'Milan Alfonsi', 'Ferdinand Flame'],
#   ['nm2099990', 'nm12766685', 'nm12766684'],
#   ['', '', ''],
#   ['Drama'],
#   110,
#   ['France'],
#   ['French'],
#   ["L'Heure d'été",
#    'Indéfilms 9',
#    'Région Grand Est',
#    'La Région Île-de-France',
#    'Image/Mouvement du Centre National des Arts Plastiques'],
#   ['co0893536', 'co0868170', 'co0627173', 'co0090770', 'co0653379'],
#   "The small town of Revin, in the French Ardennes, is preparing to elect its mayor when an unknown character announces he's running for office. This intruder is none other than an actor, who is going to drag the whole town into a political fiction.",
#   7,
#   8,
#   '',
#   ''),
#  ('tt13553662',
#   'Presque',
#   'Presque',
#   2021,
#   ['Bernard Campan', 'Alexandre Jollien'],
#   ['nm0132064', 'nm4056825'],
#   ['Bernard Campan',
#    'Alexandre Jollien',
#    'Tiphaine Daviot',
#    'Julie-Anne Roth',
#    'La Castou',
#    'Marie Benati',
#    'Marilyne Canto',
#    'Anne-Valérie Payet',
#    'Sofiia Manousha',
#    'Marie Petiot',
#    'Laëtitia Eïdo',
#    'Maurice Aufair',
#    'Roméo Henchoz',
#    'Joachim Chappuis',
#    'Annie Christ',
#    'Catherine Guggisberg',
#    'Rosette Aghiga',
#    'Barbara Tobola',
#    'Frank Semelet',
#    'Safi Marti Yé',
#    'Sarah-Laure Estragnat',
#    'Laurent Gilgen',
#    'Julien Catrix',
#    'Julien Testard',
#    'Benoît Saladino',
#    'Grégory Cartelier',
#    'Cédric Zimmerlin',
#    'Margo Santée',
#    'Fred Tournaire',
#    'Collin Collet'],
#   ['nm0132064',
#    'nm4056825',
#    'nm4401484',
#    'nm0712208',
#    'nm10815723',
#    'nm9933588',
#    'nm0134618',
#    'nm5367226',
#    'nm3809653',
#    'nm5384146',
#    'nm3128226',
#    'nm0041746',
#    'nm13330062',
#    'nm13330063',
#    'nm13330064',
#    'nm2470968',
#    'nm5754602',
#    'nm1999810',
#    'nm2508194',
#    'nm13330065',
#    'nm0261881',
#    'nm13345279',
#    'nm10958233',
#    'nm4292571',
#    'nm9113614',
#    'nm8970549',
#    'nm1822672',
#    'nm13345280',
#    'nm4978308',
#    'nm13345281'],
#   ['',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['Comedy'],
#   92,
#   ['France', 'Switzerland'],
#   ['French'],
#   ['Pan Européenne',
#    'France 3 Cinéma',
#    'Apollo Films',
#    'ABS',
#    'Les Productions JMH',
#    'Radio Télévision Suisse (RTS)',
#    'SRG - SSR',
#    'Canal+',
#    'OCS',
#    'France Télévisions',
#    'Eurimages',
#    'Région Occitanie/Pyrénées-Méditerranée',
#    "Centre national du cinéma et de l'image animée (CNC)",
#    'Office Fédéral de la Culture',
#    'Procirep',
#    'Angoa-Agicoa',
#    'Indéfilms 8',
#    'SG Image 2018',
#    'Cinéforom',
#    'Loterie Suisse Romande'],
#   ['co0060537',
#    'co0044140',
#    'co0678648',
#    'co0023544',
#    'co0043858',
#    'co0314152',
#    'co0091434',
#    'co0028557',
#    'co0624903',
#    'co0125554',
#    'co0056024',
#    'co0641403',
#    'co0090290',
#    'co0048414',
#    'co0870592',
#    'co0125559',
#    'co0772991',
#    'co0772992',
#    'co0461350',
#    'co0004392'],
#   "Two men, why vastly different life stories and personalities, embark on a Hearse heading south of France. During their journey, they realize that however unlikely, they're not so different in the end.",
#   7.4,
#   70,
#   '',
#   ''),
#  ('tt13492256',
#   'Adieu Paris',
#   'Adieu Paris',
#   2021,
#   ['Edouard Baer'],
#   ['nm0046347'],
#   ['Pierre Arditi',
#    'Jackie Berroyer',
#    'Gérard Daguerre',
#    'François Damiens',
#    'Gérard Depardieu',
#    'Léa Drucker',
#    'Bernard Le Coq',
#    'Bernard Murat',
#    'Isabelle Nanty',
#    'Yoshi Oida',
#    'Benoît Poelvoorde',
#    'Daniel Prévost',
#    'Ludivine Sagnier',
#    'Jean-François Stévenin',
#    'Zac Andianas',
#    'Edouard Baer',
#    'Krishna Bagadiya',
#    'Stéphanie Bataille',
#    'Jenny Bellay',
#    'Sigrid Bouaziz',
#    'Myriam Feune de Colombi',
#    'Rachel Khan',
#    'Christophe Meynet',
#    'Françoise Remont'],
#   ['nm0034079',
#    'nm0077449',
#    'nm1065025',
#    'nm1460782',
#    'nm0000367',
#    'nm0238475',
#    'nm0494204',
#    'nm0613573',
#    'nm0620964',
#    'nm0645224',
#    'nm0688143',
#    'nm0699545',
#    'nm0756203',
#    'nm0836681',
#    'nm4550074',
#    'nm0046347',
#    'nm9227532',
#    'nm1589768',
#    'nm1278519',
#    'nm3335498',
#    'nm0173013',
#    'nm5570940',
#    'nm1422619',
#    'nm4013207'],
#   ['',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['Comedy'],
#   96,
#   ['France', 'Belgium'],
#   ['French'],
#   ['Cinéfrance Studios',
#    'Les Productions en Cabine',
#    'Le Pacte',
#    'Artémis Productions',
#    'Canal+',
#    'Ciné+',
#    'VOO',
#    'BE TV'],
#   ['co0726043',
#    'co0073012',
#    'co0230609',
#    'co0036163',
#    'co0028557',
#    'co0346444',
#    'co0375934',
#    'co0178188'],
#   'Eight men in an old Parisian bar. They were the «kings of Paris»: national treasures, masterpieces in peril, whose humor and self-mockery have never changed. Tender and cruel, they love and hate each other. Suddenly, an intruder steps in.',
#   5.2,
#   34,
#   '',
#   ''),
#  ('tt13846472',
#   'Les promesses',
#   'Les promesses',
#   2021,
#   ['Thomas Kruithof'],
#   ['nm5535941'],
#   ['Isabelle Huppert',
#    'Reda Kateb',
#    'Naidra Ayadi',
#    'Jean-Paul Bordes',
#    'Soufiane Guerrab',
#    'Laurent Poitrenaux',
#    'Hervé Pierre',
#    'Walid Afkir',
#    'Stefan Crepon',
#    'Vincent Garanger',
#    'Anne Loiret',
#    'Youssouf Wague',
#    'Bruno Georis',
#    'Gauthier Battoue',
#    'Mama Prassinos',
#    'Christian Benedetti',
#    'Mustapha Abourachid',
#    'Rosita Dadoun Fernandez',
#    'François Perache',
#    'Alex Andréa',
#    'Brune Renault',
#    'Roukiata Ouedraogo',
#    'Sébastien Deleau',
#    'Laurent Mothe',
#    'Cécile Ribault-Caillol',
#    'Jean Seleskovitch',
#    'Philippe Dusseau',
#    'Rachel Khan',
#    'Jonas Dinal',
#    'Elsa Bougerie'],
#   ['nm0001376',
#    'nm3024530',
#    'nm1929699',
#    'nm0096195',
#    'nm2245673',
#    'nm0688648',
#    'nm0682634',
#    'nm0012715',
#    'nm9729717',
#    'nm0304826',
#    'nm0517974',
#    'nm10268870',
#    'nm0313813',
#    'nm3153293',
#    'nm0695300',
#    'nm0070694',
#    'nm3224532',
#    'nm7889595',
#    'nm5279594',
#    'nm7289523',
#    'nm3895049',
#    'nm6085434',
#    'nm5300307',
#    'nm1896791',
#    'nm8531395',
#    'nm9130482',
#    'nm4162223',
#    'nm5570940',
#    'nm5090064',
#    'nm5382091'],
#   ['',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['Drama'],
#   98,
#   ['France'],
#   ['French'],
#   ['2425 Films',
#    'Wild Bunch',
#    'France 2 Cinéma',
#    'Les Films du Camélia',
#    'Indéfilms 9',
#    'Canal+',
#    'Ciné+',
#    'France Télévisions',
#    'La Région Île-de-France',
#    'Sacem'],
#   ['co0358196',
#    'co0024845',
#    'co0056755',
#    'co0046236',
#    'co0868170',
#    'co0028557',
#    'co0346444',
#    'co0125554',
#    'co0090770',
#    'co0039449'],
#   "A story that revolves around Clemence who's in the final stage of her political career as a Mayor of Parisian suburbs.",
#   6.1,
#   167,
#   '',
#   ''),
#  ('tt11299998',
#   'Sunless Shadows',
#   'Sunless Shadows',
#   2019,
#   ['Mehrdad Oskouei'],
#   ['nm1964867'],
#   [''],
#   [''],
#   [''],
#   ['Documentary'],
#   74,
#   ['Iran', 'Norway'],
#   ['Persian'],
#   ['Film E-Emrooz', 'Indie Film as', 'Oskouei Film Production'],
#   ['co0051478', 'co0252212', 'co0402128'],
#   'In an Iranian juvenile detention center, a group of adolescent girls are serving time for having murdered their father, husband or another male family member.',
#   7.4,
#   130,
#   '',
#   ''),
#  ('tt13328732',
#   'Une jeune fille qui va bien',
#   'Une jeune fille qui va bien',
#   2021,
#   ['Sandrine Kiberlain'],
#   ['nm0452161'],
#   ['Rebecca Marder',
#    'André Marcon',
#    'Anthony Bajon',
#    'Françoise Widhoff',
#    'India Hair',
#    'Florence Viala',
#    'Ben Attal',
#    'Cyril Metzger',
#    'Jean Chevalier',
#    'Bastien Bouillon',
#    'Mathilde Weil',
#    'Théo Augier',
#    'Lucie Gallo',
#    'Stéphanie Aflalo',
#    'Arturo Giusi',
#    'Elsa Guedj',
#    'Lucie Epicuero',
#    'Jérôme Deschamps',
#    'Evelyne Istria',
#    'Léa Rostain',
#    'Frédéric Noaille',
#    'Vladislav Galard',
#    'Anne Rotger',
#    'Florence Janas',
#    'Audrey Bonnet',
#    'Pierre Léon Luneau',
#    'Juliette Duret',
#    'Lucille Arnaud',
#    'Yvon Demol',
#    'Jean Donagan'],
#   ['nm2406198',
#    'nm0545838',
#    'nm7557188',
#    'nm0927115',
#    'nm4280460',
#    'nm0895606',
#    'nm1273557',
#    'nm10743187',
#    'nm7593798',
#    'nm3319078',
#    'nm6852385',
#    'nm8914388',
#    'nm7224655',
#    'nm13225187',
#    'nm8957145',
#    'nm5794946',
#    'nm8137919',
#    'nm0221022',
#    'nm0411591',
#    'nm10087226',
#    'nm3429194',
#    'nm1957832',
#    'nm9880656',
#    'nm1211529',
#    'nm1296631',
#    'nm10239249',
#    'nm8499829',
#    'nm13276783',
#    'nm13276784',
#    'nm3758036'],
#   ['',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['Drama', 'History'],
#   98,
#   ['France'],
#   ['French'],
#   ['Curiosa Films',
#    'E.D.I Films',
#    'France 3 Cinéma',
#    'BNP Paribas Pictures',
#    'Canal+',
#    'France Télévisions',
#    'Ciné+',
#    'Cinémage 15',
#    'SG Image 2019',
#    'La Région Île-de-France'],
#   ['co0571461',
#    'co0532836',
#    'co0044140',
#    'co0726133',
#    'co0028557',
#    'co0125554',
#    'co0346444',
#    'co0841749',
#    'co0881647',
#    'co0090770'],
#   "Paris, summer 1942. Irene is Jewish and French. She is 19 and living a life of passions - Her friendships, her new love, her desire to be an actress - Nothing suggests that Irene's time is running out.",
#   5.9,
#   73,
#   2972000,
#   '€'),
#  ('tt11225756',
#   'The Lost Leonardo',
#   'The Lost Leonardo',
#   2021,
#   ['Andreas Koefoed'],
#   ['nm3572012'],
#   ['Jerry Saltz',
#    'Robert K. Wittman',
#    'Martin Kemp',
#    'Dianne Dwyer Modestini',
#    'Alexandra Bregman',
#    'Doug Patteson',
#    'David Kirkpatrick',
#    'Alison Cole',
#    'Maria Teresa Fiorio',
#    'Evan Beard',
#    'Antoine Harari',
#    'Yves Bouvier',
#    'Warren Adelson',
#    'Kenny Schacter',
#    'Alexander Parish',
#    'Robert Simon',
#    'Luke Syson',
#    'Georgina Adam',
#    'Bruce Lamarche',
#    'Stéphane Lacroix',
#    'Bernd Lindemann',
#    'Didier Rykner',
#    'Frank Zöllner',
#    'Jacques Franck',
#    'Bradley Hope',
#    'Ashok Roy'],
#   ['nm2193574',
#    'nm3970818',
#    'nm1577864',
#    'nm8778004',
#    'nm12630903',
#    'nm7324390',
#    'nm4257996',
#    'nm12750656',
#    'nm8235201',
#    'nm12660991',
#    'nm12750655',
#    'nm12750647',
#    'nm12750650',
#    'nm9786769',
#    'nm12750648',
#    'nm12750649',
#    'nm5496708',
#    'nm10366840',
#    'nm12750651',
#    'nm12750654',
#    'nm11224239',
#    'nm7943098',
#    'nm12750652',
#    'nm12750653',
#    'nm11863283',
#    'nm1643119'],
#   ['',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['Documentary'],
#   96,
#   ['Denmark', 'France'],
#   ['English', 'French'],
#   ['Elk Film', 'Mantaray Film', 'Pumpernickel Films'],
#   ['co0576054', 'co0533102', 'co0375137'],
#   "The Lost Leonardo is the inside story behind the Salvator Mundi, the most expensive painting ever sold at $450 million. From the moment the painting is bought for $1175 at a shady New Orleans auction house, and the restorer discovers masterful Renaissance brushstrokes under the heavy varnish of its cheap restoration, the Salvator Mundi's fate is determined by an insatiable quest for fame, money and power. As its price soars, so do the questions about its authenticity: is this painting really by Leonardo da Vinci? Unravelling the hidden agendas of the richest men and the most powerful art institutions in the world, The Lost Leonardo reveals how vested interests in the Salvator Mundi are of such tremendous power that truth becomes secondary.",
#   7.6,
#   611,
#   '',
#   ''),
#  ('tt12981624',
#   "Jusqu'à la mer",
#   'Mehri ti thalassa',
#   2019,
#   ['Markos Gastin'],
#   ['nm2756439'],
#   [''],
#   [''],
#   [''],
#   ['Documentary'],
#   108,
#   ['Greece', 'France'],
#   ['Greek'],
#   ['Minimal Films',
#    'Les Films du Tambour de Soie',
#    'Hellenic Radio & Television (ERT)',
#    'Greek Film Center',
#    "Centre national du cinéma et de l'image animée (CNC)",
#    "Région Provence-Alpes-Côte d'Azur",
#    "Europe Creative Media de l'Union Européenne"],
#   ['co0234028',
#    'co0017055',
#    'co0059234',
#    'co0042307',
#    'co0090290',
#    'co0285148',
#    'co0673604'],
#   'Victims of serious accidents are hospitalized at the Rehabilitation unit of a major Athenian hospital. Supported by the hospital staff, their families and ward-mates they try very hard to regain their previous abilities. For several months, they struggle daily, to re-learn basic gestures. Some will regain all their faculties. Others, due to the seriousness of their injuries, will not; they will therefore have to confront the challenge of accepting their handicap. Filmed from the point of view of four patients with mobility issues, the film explores the antinomy between hope and acceptance, one of the basic dilemmas of human existence.',
#   7.8,
#   13,
#   '',
#   ''),
#  ('tt11697794',
#   'Irradiés',
#   'Irradiés',
#   2020,
#   ['Rithy Panh'],
#   ['nm0659454'],
#   ['Rebecca Marder', 'André Wilms', 'Bion'],
#   ['nm2406198', 'nm0932870', 'nm11344321'],
#   ['V', 'V', ''],
#   ['Documentary'],
#   88,
#   ['Cambodia', 'France'],
#   ['French'],
#   ['Catherine Dussart Productions (CDP)',
#    'Anupheap Productions',
#    'France Télévisions',
#    'Creative Europe MEDIA',
#    'Procirep/Angicoa',
#    "Centre national du cinéma et de l'image animée (CNC)",
#    'Institut Français'],
#   ['co0139641',
#    'co0724465',
#    'co0125554',
#    'co0668088',
#    'co0269884',
#    'co0090290',
#    'co0503416'],
#   'A film about people who have survived the irradiation of war and is recommended to those who believe they are immune to it. An extreme, necessary film that penetrates the eye and heart with unyielding force.',
#   5.6,
#   78,
#   '',
#   ''),
#  ('tt15688362',
#   "Graines d'espoir",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('tt13345138',
#   'Asmodeus',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('tt17348968',
#   'Paysan paysage',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('tt13544716',
#   "My Hero Academia: World Heroes' Mission",
#   'Boku no Hero Academia: World Heroes Mission',
#   2021,
#   ['Kenji Nagasaki'],
#   ['nm2568279'],
#   ['Daiki Yamashita',
#    'Nobuhiko Okamoto',
#    'Yûki Kaji',
#    'Tetsu Inada',
#    'Yûichi Nakamura',
#    'Yoshimasa Hosoya',
#    'Ryô Yoshizawa',
#    'Arisa Sekine',
#    'Megumi Hayashibara',
#    'Yoko Honna',
#    'Kazuya Nakai',
#    'Mariya Ise',
#    'Yuichiro Umehara',
#    'Junya Enoki',
#    'Shogo Sakata',
#    'Yuuki Hayashi',
#    'Hirofumi Nojima',
#    'Takumu Miyazono',
#    'Toshiki Masuda',
#    'Kei Shindo',
#    'Koji Okino',
#    'Yûto Uemura',
#    'Shuhei Matsuda',
#    'Kazuyuki Okitsu',
#    'Kenta Ôkuma',
#    'Misato Kawauchi',
#    'Ayane Sakura',
#    'Aoi Yûki',
#    'Kiyono Yasuno',
#    'Kaori Yagi'],
#   ['nm5693918',
#    'nm2462004',
#    'nm2569233',
#    'nm1132505',
#    'nm1697606',
#    'nm2893431',
#    'nm4877001',
#    'nm10615157',
#    'nm0370677',
#    'nm0393365',
#    'nm0620017',
#    'nm2540995',
#    'nm6728149',
#    'nm7121595',
#    'nm9980292',
#    'nm11029465',
#    'nm1203697',
#    'nm10210606',
#    'nm7645092',
#    'nm2586309',
#    'nm9215788',
#    'nm3727237',
#    'nm8530460',
#    'nm2944424',
#    'nm5680798',
#    'nm6421486',
#    'nm4785118',
#    'nm2976492',
#    'nm4808444',
#    'nm1904413'],
#   ['V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V',
#    'V'],
#   ['Animation', 'Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   104,
#   ['Japan'],
#   ['Japanese'],
#   [''],
#   [''],
#   "When a cult of terrorists ruins a city by releasing a toxin that causes people's abilities to spiral out of control, Japan's greatest heroes spread around the world in an attempt to track down the mastermind and put him to justice.",
#   7.4,
#   1915,
#   '',
#   '')]

# %%
movie_df = pd.DataFrame(movies)

# %%
movie_keep = movie_df.drop(movie_df[movie_df[3] == ""].index)
too_soon = pd.DataFrame(movie_df[[0,1]].drop(movie_df[movie_df[3] != ""].index).values, \
            columns= ['imdb_id', 'title'])

# %%
if len(too_soon) > 0:
    f_scrap = pd.read_csv('movies_to_scrap/too_soon.csv').set_index("imdb_id")
    f_scrap_df = pd.DataFrame(f_scrap, columns= ['imdb_id', 'title'])
    too_soon = pd.concat([f_scrap_df, too_soon]).set_index("imdb_id")
    too_soon.to_csv('movies_to_scrap/too_soon.csv')

# %%
movie_keep
# Out:
#             0                                        1   \
# 0   tt13723064                 Tous mes amis sont morts
# 1    tt8493970                                 L'ennemi
# 2   tt10986222                       Nos âmes d'enfants
# 3   tt11956066                               Souterrain
# 4   tt11087960                                 Un monde
# 5   tt15067124                               Municipale
# 6   tt13553662                                  Presque
# 7   tt13492256                              Adieu Paris
# 8   tt13846472                            Les promesses
# 9   tt11299998                          Sunless Shadows
# 10  tt13328732              Une jeune fille qui va bien
# 11  tt11225756                        The Lost Leonardo
# 12  tt12981624                           Jusqu'à la mer
# 13  tt11697794                                 Irradiés
# 17  tt13544716  My Hero Academia: World Heroes' Mission
#
#                                              2     3   \
# 0              Wszyscy moi przyjaciele nie zyja  2020
# 1                                      L'ennemi  2020
# 2                                   C'mon C'mon  2021
# 3                                    Souterrain  2020
# 4                                      Un monde  2021
# 5                                    Municipale  2021
# 6                                       Presque  2021
# 7                                   Adieu Paris  2021
# 8                                 Les promesses  2021
# 9                               Sunless Shadows  2019
# 10                  Une jeune fille qui va bien  2021
# 11                            The Lost Leonardo  2021
# 12                            Mehri ti thalassa  2019
# 13                                     Irradiés  2020
# 17  Boku no Hero Academia: World Heroes Mission  2021
#
#                                      4                       5   \
# 0                           [Jan Belcl]             [nm5282441]
# 1                     [Stephan Streker]             [nm1437690]
# 2                          [Mike Mills]             [nm0590122]
# 3                       [Sophie Dupuis]             [nm2876079]
# 4                        [Laura Wandel]             [nm3218491]
# 5                       [Thomas Paulot]            [nm12766683]
# 6   [Bernard Campan, Alexandre Jollien]  [nm0132064, nm4056825]
# 7                        [Edouard Baer]             [nm0046347]
# 8                     [Thomas Kruithof]             [nm5535941]
# 9                     [Mehrdad Oskouei]             [nm1964867]
# 10                 [Sandrine Kiberlain]             [nm0452161]
# 11                    [Andreas Koefoed]             [nm3572012]
# 12                      [Markos Gastin]             [nm2756439]
# 13                         [Rithy Panh]             [nm0659454]
# 17                     [Kenji Nagasaki]             [nm2568279]
#
#                                                    6   \
# 0   [Michal Meyer, Adam Woronowicz, Julia Wieniawa...
# 1   [Jérémie Renier, Alma Jodorowsky, Emmanuelle B...
# 2   [Joaquin Phoenix, Gaby Hoffmann, Woody Norman,...
# 3   [Joakim Robillard, Jean-François Boudreau, Gui...
# 4   [Maya Vanderbeque, Günter Duret, Lena Girard V...
# 5     [Laurent Papot, Milan Alfonsi, Ferdinand Flame]
# 6   [Bernard Campan, Alexandre Jollien, Tiphaine D...
# 7   [Pierre Arditi, Jackie Berroyer, Gérard Daguer...
# 8   [Isabelle Huppert, Reda Kateb, Naidra Ayadi, J...
# 9                                                  []
# 10  [Rebecca Marder, André Marcon, Anthony Bajon, ...
# 11  [Jerry Saltz, Robert K. Wittman, Martin Kemp, ...
# 12                                                 []
# 13                [Rebecca Marder, André Wilms, Bion]
# 17  [Daiki Yamashita, Nobuhiko Okamoto, Yûki Kaji,...
#
#                                                    7   \
# 0   [nm3130314, nm0941575, nm8709489, nm8432916, n...
# 1   [nm0753737, nm2300160, nm0073384, nm9029751, n...
# 2   [nm0001618, nm0000451, nm7035760, nm1058940, n...
# 3   [nm8873841, nm1047757, nm2280428, nm0284785, n...
# 4   [nm11042810, nm10108593, nm9708142, nm6497350,...
# 5                 [nm2099990, nm12766685, nm12766684]
# 6   [nm0132064, nm4056825, nm4401484, nm0712208, n...
# 7   [nm0034079, nm0077449, nm1065025, nm1460782, n...
# 8   [nm0001376, nm3024530, nm1929699, nm0096195, n...
# 9                                                  []
# 10  [nm2406198, nm0545838, nm7557188, nm0927115, n...
# 11  [nm2193574, nm3970818, nm1577864, nm8778004, n...
# 12                                                 []
# 13                 [nm2406198, nm0932870, nm11344321]
# 17  [nm5693918, nm2462004, nm2569233, nm1132505, n...
#
#                                                    8   \
# 0   [, , , , , , , , , V, , , , , , , , , , , , , ...
# 1   [, , , , , , , , , , , , , , , , , , , , , , ,...
# 2   [, , , , , , , , , , , , , , , , , , , , , , ,...
# 3                          [, , , , , , , , , , , , ]
# 4           [, , , , , , , , , , , , , , , , , , , V]
# 5                                              [, , ]
# 6   [, , , , , , , , , , , , , , , , , , , , , , ,...
# 7    [, , , , , , , , , , , , , , , , , , , , , , , ]
# 8   [, , , , , , , , , , , , , , , , , , , , , , ,...
# 9                                                  []
# 10  [, , , , , , , , , , , , , , , , , , , , , , ,...
# 11  [, , , , , , , , , , , , , , , , , , , , , , ,...
# 12                                                 []
# 13                                           [V, V, ]
# 17  [V, V, V, V, V, V, V, V, V, V, V, V, V, V, V, ...
#
#                                                  9    10  \
# 0                            [Comedy, Crime, Drama]   96
# 1                                    [Crime, Drama]  105
# 2                                           [Drama]  109
# 3                                           [Drama]   97
# 4                                           [Drama]   72
# 5                                           [Drama]  110
# 6                                          [Comedy]   92
# 7                                          [Comedy]   96
# 8                                           [Drama]   98
# 9                                     [Documentary]   74
# 10                                 [Drama, History]   98
# 11                                    [Documentary]   96
# 12                                    [Documentary]  108
# 13                                    [Documentary]   88
# 17  [Animation, Action, Adventure, Fantasy, Sci-Fi]  104
#
#                                11                 12  \
# 0                        [Poland]   [Polish, French]
# 1   [Belgium, France, Luxembourg]  [French, Flemish]
# 2                           [USA]          [English]
# 3                        [Canada]           [French]
# 4                       [Belgium]           [French]
# 5                        [France]           [French]
# 6           [France, Switzerland]           [French]
# 7               [France, Belgium]           [French]
# 8                        [France]           [French]
# 9                  [Iran, Norway]          [Persian]
# 10                       [France]           [French]
# 11              [Denmark, France]  [English, French]
# 12               [Greece, France]            [Greek]
# 13             [Cambodia, France]           [French]
# 17                        [Japan]         [Japanese]
#
#                                                    13  \
# 0                                        [Aurum Film]
# 1   [Daylight Films, Formosa Productions, BAC Ciné...
# 2                        [A24, Be Funny When You Can]
# 3   [Bravo Charlie, Bord Cadre Films, SODEC, Sover...
# 4   [Dragons Films, Lunanime, Centre du Cinéma et ...
# 5   [L'Heure d'été, Indéfilms 9, Région Grand Est,...
# 6   [Pan Européenne, France 3 Cinéma, Apollo Films...
# 7   [Cinéfrance Studios, Les Productions en Cabine...
# 8   [2425 Films, Wild Bunch, France 2 Cinéma, Les ...
# 9   [Film E-Emrooz, Indie Film as, Oskouei Film Pr...
# 10  [Curiosa Films, E.D.I Films, France 3 Cinéma, ...
# 11      [Elk Film, Mantaray Film, Pumpernickel Films]
# 12  [Minimal Films, Les Films du Tambour de Soie, ...
# 13  [Catherine Dussart Productions (CDP), Anupheap...
# 17                                                 []
#
#                                                    14  \
# 0                                         [co0517033]
# 1   [co0592341, co0097625, co0847566, co0011677, c...
# 2                              [co0390816, co0879142]
# 3   [co0664701, co0149598, co0299307, co0137361, c...
# 4   [co0211102, co0310366, co0009031, co0109106, c...
# 5   [co0893536, co0868170, co0627173, co0090770, c...
# 6   [co0060537, co0044140, co0678648, co0023544, c...
# 7   [co0726043, co0073012, co0230609, co0036163, c...
# 8   [co0358196, co0024845, co0056755, co0046236, c...
# 9                   [co0051478, co0252212, co0402128]
# 10  [co0571461, co0532836, co0044140, co0726133, c...
# 11                  [co0576054, co0533102, co0375137]
# 12  [co0234028, co0017055, co0059234, co0042307, c...
# 13  [co0139641, co0724465, co0125554, co0668088, c...
# 17                                                 []
#
#                                                    15   16     17       18 19
# 0   During the New Year's Eve party of a bunch of ...  5.8   5921
# 1   Prominent politician Louis Durieux is accused ...  6.7     81
# 2   When his sister asks him to look after her son...  7.6  12610
# 3   Maxime is a miner with a troubled past. After ...  7.1    208
# 4   When Nora witnesses Abel being bullied by othe...  7.3    847  1000000  €
# 5   The small town of Revin, in the French Ardenne...    7      8
# 6   Two men, why vastly different life stories and...  7.4     70
# 7   Eight men in an old Parisian bar. They were th...  5.2     34
# 8   A story that revolves around Clemence who's in...  6.1    167
# 9   In an Iranian juvenile detention center, a gro...  7.4    130
# 10  Paris, summer 1942. Irene is Jewish and French...  5.9     73  2972000  €
# 11  The Lost Leonardo is the inside story behind t...  7.6    611
# 12  Victims of serious accidents are hospitalized ...  7.8     13
# 13  A film about people who have survived the irra...  5.6     78
# 17  When a cult of terrorists ruins a city by rele...  7.4   1915

# %% [markdown]
# ## Lists of data

# %%
    imdb = list(movie_keep[0].values)
    title = list(movie_keep[1].values)
    original_title = list(movie_keep[2].values)
    year = list(movie_keep[3].values)
    director = list(movie_keep[4].values)
    dir_code = list(movie_keep[5].values)
    actor = list(movie_keep[6].values)
    actor_code = list(movie_keep[7].values)
    actor_status = list(movie_keep[8].values)
    genres = list(movie_keep[9].values)
    duration = list(movie_keep[10].values)
    country = list(movie_keep[11].values)
    language = list(movie_keep[12].values)
    production = list(movie_keep[13].values)
    prod_code = list(movie_keep[14].values)
    synopsis = list(movie_keep[15].values)
    rating = list(movie_keep[16].values)
    num_rate = list(movie_keep[17].values)
    budget = list(movie_keep[18].values)
    bud_currency = list(movie_keep[19].values)
    saw = ["" for i in range(len(imdb))]
    db_saw = [False for i in range(len(imdb))]

# %% [markdown]
# ## Update country_sql

# %%
state_df = pd.read_csv('db_backup/country_db.csv')

# %%
code_state = list(state_df.country_id.values)
countries = list(state_df.name.values)

# %%
max_country_id = max(code_state)

# %%
update_state = []
update_state_code = []

# %%
for i in range(len(country)):
    for j in range(len(country[i])):
        if country[i][j] not in countries and country[i][j] != "":
            update_state.append(country[i][j])
            update_state_code.append(max_country_id + 1)
            max_country_id += 1

# %%
state_data = {"country_id": update_state_code, "name": update_state}

# %%
up_country = pd.DataFrame(state_data).set_index("country_id")
country_df = pd.concat([state_df, up_country])

# %%
for i in range(len(category)):    
    for j in range(len(imdb)):
        for j in range(len(category[k][i])):
            if ids == imdb[i]:
                temp_cat.append(category[k][i][j])
            elif ids != imdb[i]:
                dict_cat[ids] = " | ".join(temp_cat)
                ids = imdb[i]
                temp_cat = []
                temp_cat.append(category[k][i][j])
        dict_cat[ids] = " | ".join(temp_cat)

# %%
country_code = [int(country_df.country_id.values[list(country_df.name.values).index(country[i][j])]) \
                for i in range(len(country)) for j in range(len(country[i]))]

# %%
if len(up_country) > 0:
    up_country.to_csv("update_db/up_country.csv")

# %% [markdown]
# ## Update language_sql

# %%
lan_df = pd.read_csv('db_backup/language_db.csv')

# %%
code_lan = list(lan_df.language_id.values)
lan = list(lan_df.name.values)

# %%
max_language_id = max(code_lan)

# %%
update_lan = []
update_lan_code = []

# %%
for i in range(len(language)):
    for j in range(len(language[i])):
        if language[i][j] not in lan and language[i][j] != "":
            update_lan.append(language[i][j])
            update_lan_code.append(max_language_id + 1)
            max_language_id += 1

# %%
lan_data = {"language_id": update_lan_code, "name": update_lan}

# %%
up_language = pd.DataFrame(lan_data)

# %%
language_df = pd.concat([lan_df, up_language])

# %%
language_code = [int(language_df.language_id.values[list(language_df.name.values).index(language[i][j])]) \
                for i in range(len(language)) for j in range(len(language[i]))]

# %%
up_language
# Out:
# Empty DataFrame
# Columns: [language_id, name]
# Index: []

# %%
if len(up_language) > 0:
    up_language.to_csv("update_db/up_language.csv")

# %% [markdown]
# ## Creation of genre_code, country_code and language_code for data

# %%
genre_df = pd.read_csv("db_backup/genre_db.csv")
genre_code = [genre_df.genre_id.values[list(genre_df.name.values).index(genres[i][j])] \
            for i in range(len(genres)) for j in range(len(genres[i]))]

# %% [markdown]
# ## Make change of currencies

# %%
changer = pd.read_excel("currency_change.xlsx")

# %%
changer = {"$":1, "€":1.17, "£":1.37}
def_budget = [changer[bud_currency[i]]*budget[i] if budget[i] != "" else "" for i in range(len(budget))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-234b46d61283> in <module>
#       1 changer = {"$":1, "€":1.17, "£":1.37}
# ----> 2 def_budget = [changer[bud_currency[i]]*budget[i] if budget[i] != "" else "" for i in range(len(budget))]
#
# <ipython-input-17-234b46d61283> in <listcomp>(.0)
#       1 changer = {"$":1, "€":1.17, "£":1.37}
# ----> 2 def_budget = [changer[bud_currency[i]]*budget[i] if budget[i] != "" else "" for i in range(len(budget))]
#
# KeyError: ''

# %% [markdown]
# ## Update selection_film

# %% [markdown]
# #### List to string for directors, actors, genres, countries, language, production

# %%
dict_dir = {}
dict_cast = {}
dict_genre = {}
dict_country = {}
dict_language = {}
dict_prod = {}

# %%
temp_dir = []
temp_cast = []
temp_genre = []
temp_country = []
temp_language = []
temp_prod = []

# %%
ids = imdb[0]

# %%
for i in range(len(imdb)):
    for j in range(len(director[i])):
        if ids == imdb[i]:
            temp_dir.append(director[i][j]) 
        elif ids != imdb[i]:
            dict_dir[ids] = " | ".join(temp_dir)
            ids = imdb[i]
            temp_dir = []
            temp_dir.append(director[i][j])
    dict_dir[ids] = " | ".join(temp_dir)

# %%
director
# Out:
# [['Jan Belcl'],
#  ['Stephan Streker'],
#  ['Mike Mills'],
#  ['Sophie Dupuis'],
#  ['Laura Wandel'],
#  ['Thomas Paulot'],
#  ['Bernard Campan', 'Alexandre Jollien'],
#  ['Edouard Baer'],
#  ['Thomas Kruithof'],
#  ['Mehrdad Oskouei'],
#  ['Sandrine Kiberlain'],
#  ['Andreas Koefoed'],
#  ['Markos Gastin'],
#  ['Rithy Panh'],
#  ['Kenji Nagasaki']]

# %%
ids = imdb[0]

# %%
for i in range(len(imdb)):
    for j in range(len(actor[i])):
        if ids == imdb[i]:
            temp_cast.append(actor[i][j])
        elif ids != imdb[i]:
            dict_cast[ids] = " | ".join(temp_cast)
            ids = imdb[i]
            temp_cast = []
            temp_cast.append(actor[i][j])
    dict_cast[ids] = " | ".join(temp_cast)

# %%
ids = imdb[0]

# %%
for i in range(len(imdb)):
    for j in range(len(genres[i])):
        if ids == imdb[i]:
            temp_genre.append(genres[i][j])
        elif ids != imdb[i]:
            dict_genre[ids] = " | ".join(temp_genre)
            ids = imdb[i]
            temp_genre = []
            temp_genre.append(genres[i][j])
    dict_genre[ids] = " | ".join(temp_genre)

# %%
ids = imdb[0]

# %%
country
# Out:
# [['Poland'],
#  ['Belgium', 'France', 'Luxembourg'],
#  ['USA'],
#  ['Canada'],
#  ['Belgium'],
#  ['France'],
#  ['France', 'Switzerland'],
#  ['France', 'Belgium'],
#  ['France'],
#  ['Iran', 'Norway'],
#  ['France'],
#  ['Denmark', 'France'],
#  ['Greece', 'France'],
#  ['Cambodia', 'France'],
#  ['Japan']]

# %%
for i in range(len(imdb)):
    for j in range(len(country[i])):
        if ids == imdb[i]:
            temp_country.append(country[i][j])
        elif ids != imdb[i]:
            dict_country[ids] = " | ".join(temp_country)
            ids = imdb[i]
            temp_country = []
            temp_country.append(country[i][j])
    dict_country[ids] = " | ".join(temp_country)

# %%
ids = imdb[0]

# %%
for i in range(len(imdb)):
    for j in range(len(language[i])):
        if ids == imdb[i]:
            temp_language.append(language[i][j])
        elif ids != imdb[i]:
            dict_language[ids] = " | ".join(temp_language)
            ids = imdb[i]
            temp_language = []
            temp_language.append(language[i][j])
    dict_language[ids] = " | ".join(temp_language)

# %%
ids = imdb[0]

# %%
for i in range(len(imdb)):
    for j in range(len(production[i])):
        if ids == imdb[i]:
            temp_prod.append(production[i][j])
        elif ids != imdb[i]:
            dict_prod[ids] = " | ".join(temp_prod)
            ids = imdb[i]
            temp_prod = []
            temp_prod.append(production[i][j])
    dict_prod[ids] = " | ".join(temp_prod)

# %% [markdown]
# #### Put data in a dataframe

# %%
select_data = {"imdb_id": imdb, "vu": saw, "à voir": saw, "title": title, "original_title": original_title, \
               "year": year, "director": list(dict_dir.values()), "casting": list(dict_cast.values()), \
               "genres": list(dict_genre.values()), "duration": duration, \
               "country": list(dict_country.values()), "language": list(dict_language.values()), \
               "production": list(dict_prod.values()), "synopsis": synopsis, "rating": rating, \
               "num_rate": num_rate}

# %%
select = pd.DataFrame(select_data).set_index("imdb_id")

# %%
select
# Out:
#            vu à voir                                    title  \
# imdb_id
# tt13723064                           Tous mes amis sont morts
# tt8493970                                            L'ennemi
# tt10986222                                 Nos âmes d'enfants
# tt11956066                                         Souterrain
# tt11087960                                           Un monde
# tt15067124                                         Municipale
# tt13553662                                            Presque
# tt13492256                                        Adieu Paris
# tt13846472                                      Les promesses
# tt11299998                                    Sunless Shadows
# tt13328732                        Une jeune fille qui va bien
# tt11225756                                  The Lost Leonardo
# tt12981624                                     Jusqu'à la mer
# tt11697794                                           Irradiés
# tt13544716            My Hero Academia: World Heroes' Mission
#
#                                          original_title  year  \
# imdb_id
# tt13723064             Wszyscy moi przyjaciele nie zyja  2020
# tt8493970                                      L'ennemi  2020
# tt10986222                                  C'mon C'mon  2021
# tt11956066                                   Souterrain  2020
# tt11087960                                     Un monde  2021
# tt15067124                                   Municipale  2021
# tt13553662                                      Presque  2021
# tt13492256                                  Adieu Paris  2021
# tt13846472                                Les promesses  2021
# tt11299998                              Sunless Shadows  2019
# tt13328732                  Une jeune fille qui va bien  2021
# tt11225756                            The Lost Leonardo  2021
# tt12981624                            Mehri ti thalassa  2019
# tt11697794                                     Irradiés  2020
# tt13544716  Boku no Hero Academia: World Heroes Mission  2021
#
#                                       director  \
# imdb_id
# tt13723064                           Jan Belcl
# tt8493970                      Stephan Streker
# tt10986222                          Mike Mills
# tt11956066                       Sophie Dupuis
# tt11087960                        Laura Wandel
# tt15067124                       Thomas Paulot
# tt13553662  Bernard Campan | Alexandre Jollien
# tt13492256                        Edouard Baer
# tt13846472                     Thomas Kruithof
# tt11299998                     Mehrdad Oskouei
# tt13328732                  Sandrine Kiberlain
# tt11225756                     Andreas Koefoed
# tt12981624                       Markos Gastin
# tt11697794                          Rithy Panh
# tt13544716                      Kenji Nagasaki
#
#                                                       casting  \
# imdb_id
# tt13723064  Michal Meyer | Adam Woronowicz | Julia Wieniaw...
# tt8493970   Jérémie Renier | Alma Jodorowsky | Emmanuelle ...
# tt10986222  Joaquin Phoenix | Gaby Hoffmann | Woody Norman...
# tt11956066  Joakim Robillard | Jean-François Boudreau | Gu...
# tt11087960  Maya Vanderbeque | Günter Duret | Lena Girard ...
# tt15067124    Laurent Papot | Milan Alfonsi | Ferdinand Flame
# tt13553662  Bernard Campan | Alexandre Jollien | Tiphaine ...
# tt13492256  Pierre Arditi | Jackie Berroyer | Gérard Dague...
# tt13846472  Isabelle Huppert | Reda Kateb | Naidra Ayadi |...
# tt11299998
# tt13328732  Rebecca Marder | André Marcon | Anthony Bajon ...
# tt11225756  Jerry Saltz | Robert K. Wittman | Martin Kemp ...
# tt12981624
# tt11697794                Rebecca Marder | André Wilms | Bion
# tt13544716  Daiki Yamashita | Nobuhiko Okamoto | Yûki Kaji...
#
#                                                        genres  duration  \
# imdb_id
# tt13723064                             Comedy | Crime | Drama        96
# tt8493970                                       Crime | Drama       105
# tt10986222                                              Drama       109
# tt11956066                                              Drama        97
# tt11087960                                              Drama        72
# tt15067124                                              Drama       110
# tt13553662                                             Comedy        92
# tt13492256                                             Comedy        96
# tt13846472                                              Drama        98
# tt11299998                                        Documentary        74
# tt13328732                                    Drama | History        98
# tt11225756                                        Documentary        96
# tt12981624                                        Documentary       108
# tt11697794                                        Documentary        88
# tt13544716  Animation | Action | Adventure | Fantasy | Sci-Fi       104
#
#                                   country          language  \
# imdb_id
# tt13723064                         Poland   Polish | French
# tt8493970   Belgium | France | Luxembourg  French | Flemish
# tt10986222                            USA           English
# tt11956066                         Canada            French
# tt11087960                        Belgium            French
# tt15067124                         France            French
# tt13553662           France | Switzerland            French
# tt13492256               France | Belgium            French
# tt13846472                         France            French
# tt11299998                  Iran | Norway           Persian
# tt13328732                         France            French
# tt11225756               Denmark | France  English | French
# tt12981624                Greece | France             Greek
# tt11697794              Cambodia | France            French
# tt13544716                          Japan          Japanese
#
#                                                    production  \
# imdb_id
# tt13723064                                         Aurum Film
# tt8493970   Daylight Films | Formosa Productions | BAC Cin...
# tt10986222                        A24 | Be Funny When You Can
# tt11956066  Bravo Charlie | Bord Cadre Films | SODEC | Sov...
# tt11087960  Dragons Films | Lunanime | Centre du Cinéma et...
# tt15067124  L'Heure d'été | Indéfilms 9 | Région Grand Est...
# tt13553662  Pan Européenne | France 3 Cinéma | Apollo Film...
# tt13492256  Cinéfrance Studios | Les Productions en Cabine...
# tt13846472  2425 Films | Wild Bunch | France 2 Cinéma | Le...
# tt11299998  Film E-Emrooz | Indie Film as | Oskouei Film P...
# tt13328732  Curiosa Films | E.D.I Films | France 3 Cinéma ...
# tt11225756      Elk Film | Mantaray Film | Pumpernickel Films
# tt12981624  Minimal Films | Les Films du Tambour de Soie |...
# tt11697794  Catherine Dussart Productions (CDP) | Anupheap...
# tt13544716
#
#                                                      synopsis  rating  \
# imdb_id
# tt13723064  During the New Year's Eve party of a bunch of ...     5.8
# tt8493970   Prominent politician Louis Durieux is accused ...     6.7
# tt10986222  When his sister asks him to look after her son...     7.6
# tt11956066  Maxime is a miner with a troubled past. After ...     7.1
# tt11087960  When Nora witnesses Abel being bullied by othe...     7.3
# tt15067124  The small town of Revin, in the French Ardenne...     7.0
# tt13553662  Two men, why vastly different life stories and...     7.4
# tt13492256  Eight men in an old Parisian bar. They were th...     5.2
# tt13846472  A story that revolves around Clemence who's in...     6.1
# tt11299998  In an Iranian juvenile detention center, a gro...     7.4
# tt13328732  Paris, summer 1942. Irene is Jewish and French...     5.9
# tt11225756  The Lost Leonardo is the inside story behind t...     7.6
# tt12981624  Victims of serious accidents are hospitalized ...     7.8
# tt11697794  A film about people who have survived the irra...     5.6
# tt13544716  When a cult of terrorists ruins a city by rele...     7.4
#
#             num_rate
# imdb_id
# tt13723064      5921
# tt8493970         81
# tt10986222     12610
# tt11956066       208
# tt11087960       847
# tt15067124         8
# tt13553662        70
# tt13492256        34
# tt13846472       167
# tt11299998       130
# tt13328732        73
# tt11225756       611
# tt12981624        13
# tt11697794        78
# tt13544716      1915

# %%
select.to_csv("movies_scraped.csv")

# %% [markdown]
# ## Update movie_sql

# %%
movie_data = {"imdb_id": imdb, "title": title, "original_title": original_title, "year": year, \
               "duration": duration, "rating": rating, "num_rate": num_rate, "budget": def_budget, \
               "synopsis": synopsis}

# %%
up_movie = pd.DataFrame(movie_data).set_index("imdb_id")

# %%
up_movie.to_csv("update_sql/up_movies.csv")

# %% [markdown]
# ## Update user_db

# %%
user_data = {"imdb_id": imdb, "saw": db_saw, "wishlist": db_saw}

# %%
up_user = pd.DataFrame(user_data).set_index("imdb_id")

# %%
up_user.to_csv("update_db/up_user.csv")

# %% [markdown]
# ## Update actor_sql

# %%
actor_df = pd.read_csv('new_sql/actor_sql.csv')

# %%
code_actor = list(actor_df.code.values)

# %%
update_cast_code = []
update_cast = []

# %%
for i in range(len(cast_code)): 
    for j in range(len(cast_code[i])):
        if cast_code[i][j] not in code_actor:
            update_cast_code.append(cast_code[i][j])
            update_cast.append(cast[i][j])
            code_actor.append(cast_code[i][j])

# %%
actor_data = {"actor_id": update_cast_code, "name": update_cast}

# %%
up_actor = pd.DataFrame(actor_data)

# %%
up_actor = up_actor.drop(up_actor[up_actor["actor_id"] == ""].index).set_index("actor_id")

# %%
if len(update_cast) > 0:
    up_actor.to_csv("update_sql/up_actor.csv")

# %% [markdown]
# ## Update director_sql

# %%
dir_df = pd.read_csv('new_sql/director_sql.csv')

# %%
code_dir = list(dir_df.code_name.values)

# %%
update_dir_code = []
update_dir = []

# %%
for i in range(len(dir_code)): 
    for j in range(len(dir_code[i])):
        if dir_code[i][j] not in code_dir:
            update_dir_code.append(dir_code[i][j])
            update_dir.append(director[i][j])
            code_dir.append(dir_code[i][j])

# %%
dir_data = {"director_id": update_dir_code, "name": update_dir}

# %%
up_dir = pd.DataFrame(dir_data)

# %%
up_dir = up_dir.drop(up_dir[up_dir["director_id"] == ""].index).set_index("director_id")

# %%
if len(update_dir) > 0:
    up_dir.to_csv("update_sql/up_dir.csv")

# %% [markdown]
# ## Update production_sql

# %%
prod_df = pd.read_csv('new_sql/production_sql.csv')

# %%
code_prod = list(prod_df.prod_code.values)

# %%
update_prod_code = []
update_prod = []

# %%
for i in range(len(prod_code)): 
    for j in range(len(prod_code[i])):
        if prod_code[i][j] not in code_prod:
            update_prod_code.append(prod_code[i][j])
            update_prod.append(production[i][j])
            code_prod.append(prod_code[i][j])

# %%
prod_data = {"prod_id": update_prod_code, "name": update_prod}

# %%
up_prod = pd.DataFrame(prod_data)

# %%
up_prod = up_prod.drop(up_prod[up_prod["prod_id"] == ""].index).set_index("prod_id")

# %%
if len(update_prod) > 0:
    up_prod.to_csv("update_sql/up_prod.csv")

# %% [markdown]
# ## Update movie_dir_sql

# %%
dir_imdb = [imdb[i] for i in range(len(imdb)) for j in range(len(dir_code[i]))]
all_dir = [dir_code[i][j] for i in range(len(imdb)) for j in range(len(dir_code[i]))]

# %%
movie_dir_data = {"movie_id": dir_imdb, "director_id": all_dir}

# %%
up_movie_dir = pd.DataFrame(movie_dir_data)

# %%
up_movie_dir = up_movie_dir.drop(up_movie_dir[up_movie_dir["director_id"] == ""].index).set_index("movie_id")

# %%
up_movie_dir.to_csv("update_sql/up_movie_dir.csv")

# %% [markdown]
# ## Update movie_actor_sql

# %%
cast_imdb = [imdb[i] for i in range(len(imdb)) for j in range(len(cast_code[i]))]
all_actor = [cast_code[i][j] for i in range(len(imdb)) for j in range(len(cast_code[i]))]

# %%
movie_cast_data = {"movie_id": cast_imdb, "actor_id": all_actor}

# %%
up_movie_cast = pd.DataFrame(movie_cast_data)

# %%
up_movie_cast = up_movie_cast.drop(up_movie_cast[up_movie_cast["actor_id"] == ""].index).set_index("movie_id")

# %%
up_movie_cast.to_csv("update_sql/up_movie_cast.csv")

# %% [markdown]
# ## Update movie_prod_sql

# %%
prod_imdb = [imdb[i] for i in range(len(imdb)) for j in range(len(prod_code[i]))]
all_prod = [prod_code[i][j] for i in range(len(imdb)) for j in range(len(prod_code[i]))]

# %%
movie_prod_data = {"movie_id": prod_imdb, "prod_id": all_prod}

# %%
up_movie_prod = pd.DataFrame(movie_prod_data)

# %%
up_movie_prod = up_movie_prod.drop(up_movie_prod[up_movie_prod["prod_id"] == ""].index).set_index("movie_id")

# %%
up_movie_prod.to_csv("update_sql/up_movie_prod.csv")

# %% [markdown]
# ## Update movie_genre_sql

# %%
genre_imdb = [imdb[i] for i in range(len(imdb)) for j in range(len(genres[i]))]

# %%
movie_genre_data = {"movie_id": genre_imdb, "genre_id": genre_code}

# %%
up_movie_genre = pd.DataFrame(movie_genre_data)

# %%
up_movie_genre = up_movie_genre.drop(up_movie_genre[up_movie_genre["genre_id"] == ""].index).set_index("movie_id")

# %%
up_movie_genre.to_csv("update_sql/up_movie_genre.csv")

# %% [markdown]
# ## Update movie_country_sql

# %%
country_imdb = [imdb[i] for i in range(len(imdb)) for j in range(len(country[i]))]

# %%
country_imdb
# Out:
# ['tt6013920', 'tt6013920', 'tt11286314']

# %%
movie_country_data = {"movie_id": country_imdb, "country_id": country_code}

# %%
up_movie_country = pd.DataFrame(movie_country_data)

# %%
up_movie_country = up_movie_country.drop(up_movie_country[up_movie_country["country_id"] == ""].index).set_index("movie_id")

# %%
up_movie_country.to_csv("update_sql/up_movie_country.csv")

# %% [markdown]
# ## Update movie_language_sql

# %%
language_imdb = [imdb[i] for i in range(len(imdb)) for j in range(len(language[i]))]

# %%
movie_language_data = {"movie_id": language_imdb, "language_id": language_code}

# %%
up_movie_language = pd.DataFrame(movie_language_data)

# %%
up_movie_language = up_movie_language.drop(up_movie_language[up_movie_language["language_id"] == ""].index).set_index("movie_id")

# %%
up_movie_language.to_csv("update_sql/up_movie_language.csv
