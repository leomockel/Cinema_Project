# %%
import sqlalchemy as db
import psycopg2
import pandas as pd

# %%
DATABASE_URL = "postgresql+psycopg2://postgres:root@localhost:5432/cinema_db"

# %%
engine = db.create_engine(DATABASE_URL)

# %%
connection = engine.connect()

# %%
connection

# %%
print(engine.table_names())
# Out:
# ['actors', 'directors', 'genres', 'language', 'country', 'production', 'movies', 'movie_actor', 'movie_prod', 'movie_genre', 'movie_language', 'movie_country', 'movie_director', 'user_list']

# %%
movies = db.Table('movies', metadata, autoload=True, autoload_with=engine)

# %%
print(db.select([movies]))
# Out:
# SELECT movies.imdb_id, movies.french_title, movies.original_title, movies.year, movies.duration, movies.rating, movies.num_rate, movies.budget, movies.synopsis
# FROM movies

# %%
pd.DataFrame(connection.execute(db.select([movies])).fetchall())
# Out:
#                 0                               1  \
# 0       tt0416449                             300
# 1       tt8579674                            1917
# 2       tt0078723                            1941
# 3       tt1190080                            2012
# 4       tt1022603            (500) jours ensemble
# ...           ...                             ...
# 86449  tt11905848  L'État du Texas contre Melissa
# 86450   tt7681868     Christo - Marcher sur l'eau
# 86451  tt10196108                 Eugénie Grandet
# 86452  tt14032336            Sivakumarin Sabadham
# 86453  tt15292474                 Rudra Thandavam
#
#                                     2     3      4    5         6  \
# 0                                 300  2006  117.0  7.6  735564.0
# 1                                1917  2019  119.0  8.3  439726.0
# 2                                1941  1979  118.0  5.8   31504.0
# 3                                2012  2009  158.0  5.8  354979.0
# ...

# %%
results = result_proxy.fetchall()

# %%
pd.DataFrame(results)
# Out:
#                 0                               1  \
# 0       tt0416449                             300
# 1       tt8579674                            1917
# 2       tt0078723                            1941
# 3       tt1190080                            2012
# 4       tt1022603            (500) jours ensemble
# ...           ...                             ...
# 86449  tt11905848  L'État du Texas contre Melissa
# 86450   tt7681868     Christo - Marcher sur l'eau
# 86451  tt10196108                 Eugénie Grandet
# 86452  tt14032336            Sivakumarin Sabadham
# 86453  tt15292474                 Rudra Thandavam
#
#                                     2     3      4    5         6  \
# 0                                 300  2006  117.0  7.6  735564.0
# 1                                1917  2019  119.0  8.3  439726.0
# 2                                1941  1979  118.0  5.8   31504.0
# 3                                2012  2009  158.0  5.8  354979.0
# ...

# %%
df = pd.read_csv('update_db/up_actor.csv')

# %%
df
# Out:
#      actor_id                name
# 0  nm11370123  Christiana Montoya
# 1   nm8512386    Oscar Balderrama
# 2  nm12931937       Jonathan Hunt

# %%
df.to_sql("movies", engine, if_exists="append")
